# %% [markdown]
# # Plotting Agent Demo
# - GitHub repo: https://github.com/Bawerlacher/Plotting_Agent
# - Screencast: https://www.youtube.com/watch?v=-WoGMEQLCjU

# %%
import plot_agent as pa

# %%
import nltk
nltk.download('punkt')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
model_address_1 = 'models/s2s_single.pt'
model_address_2 = 'models/s2s_single_layer_3.pt'
model_address_3 = 'models/s2s_single_size_256.pt'
src_address = 'data/s2s_single/src-train.txt'

# %% [markdown]
# ### Special Instructions:
# undo          - undo the last natural language instruction. <br>
# redo          - redo the last undo. <br>
# reset         - reset the plot specs, data and undo/redo stacks. <br>
# plot          - draw the graph with current plot specs and data. <br>
# exit          - end the current session with the plotting agent. <br>
# next          - after loading source dialog, switch to the next dialog in the dataset. <br>
# generate data - generate a dataset from data sampler according to the current plot specs. <br>
# set labels    - set the labels of the plot manually. <br>
# set fix color - set a personalized fix color and use it in later instructions. <br>
# load source dialog - load dialogs from the training/test set whose path is specified by src_address. <br>
# load csv - load data from a csv file. (user's upload is not supported in Binder. Enter "data/example/covid19_confirmed_us.csv" for the path) <br>
# load dialog - load customized dialogs from a file. <br>
# feedback - enable the feedback mode. Type in again to exit.

# %% [markdown]
# ### Quick Start:
# 1. Run the cell below.
# 2. Enter "line chart" to specify the plot type.
# 3. Enter natural language instructions like "color the line red please" to modify the plot.

# %%
agt = pa.plot_agent(model_address_1, model_address_2, model_address_3, src_address)
agt.interface()
